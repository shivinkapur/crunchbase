# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import brewer2mpl

# %%
companies = pd.read_csv('/Users/Work/Documents/CS249/project/crunchbase/Data/companies.csv')
companies=companies.dropna(how='all')
companies=companies.replace(np.nan, '0')
companies['funding_total_usd']=companies['funding_total_usd'].str.replace(',','')
companies.funding_total_usd = companies.funding_total_usd.astype('float64')
companies['founded_at']= pd.to_datetime(companies['founded_at'])
companies['first_funding_at']= pd.to_datetime(companies['first_funding_at'])
companies['last_funding_at']= pd.to_datetime(companies['last_funding_at'])
companies['last_milestone_at']= pd.to_datetime(companies['last_milestone_at'])
companies['founded_year']=companies.founded_year.astype('int')

print(companies.dtypes)
companies
# Out:
# permalink             object
# name                  object
# homepage_url          object
# category_code         object
# funding_total_usd    float64
# status                object
# country_code          object
# state_code            object
# region                object
# city                  object
# funding_rounds         int64
# founded_at            object
# founded_month         object
# founded_quarter       object
# founded_year           int64
# first_funding_at      object
# last_funding_at       object
# last_milestone_at     object
# dtype: object
#                       permalink                name  \
# 0     /company/canal-do-credito    Canal do Credito
# 1              /company/waywire            #waywire
# 2    /company/tv-communications  &TV Communications
# 3    /company/rock-your-paper-2   'Rock' Your Paper
# 4     /company/in-touch-network   (In)Touch Network
# 5              /company/n-plusn              #NAME?
# 6         /company/club-domains       .Club Domains
# 7         /company/fox-networks       .Fox Networks
# 8              /company/0-6-com             0-6.com
# 9               /company/0xdata              0xdata
# 10         /company/1-2-3-listo         1,2,3 Listo
# 11       /company/1-800-dentist       1-800-DENTIST
# 12       /company/1-800-doctors       1-800-DOCTORS
# 13         /company/10-20-media         10-20 Media
# 14          /company/1000-corks          1000 Corks
# 15        /company/1000-markets        1000 Markets
# 16   /company/1000jobboersen-de   1000jobboersen.de
# 17        /company/1000memories        1000memories
# 18     /company/1000museums-com     1000museums.com
# 19          /company/1001-menus          1001 Menus
# 20            /company/100du-tv            100du.tv
# 21            /company/100e-com            100e.com
# 22             /company/100plus             100Plus
# 23            /company/1010data            1010data
# 24             /company/10alike             10alike
# 25        /company/10bestthings        10BestThings
# 26  /company/10seconds-software  10seconds Software
# 27    /company/10x-technologies    10X Technologies
# 28          /company/10x10-room          10X10 Room
# 29       /company/11i-solutions       11i Solutions
# 30             /company/121cast             121cast
# 31            /company/121nexus            121nexus
# 32           /company/1234enter           1234ENTER
# 33      /company/123contactform      123ContactForm
# 34           /company/123people           123people
# 35                /company/1248                1248
# 36           /company/12society           12Society
# 37   /company/1366-technologies   1366 Technologies
# 38             /company/139shop             139shop
# 39            /company/13th-lab            13th Lab
# 40           /company/140-proof           140 Proof
# 41             /company/140fire             140Fire
# 42   /company/phoneuser-network             159.com
# 43              /company/15five              15Five
# 44        /company/15minutesnow        15MinutesNOW
# 45   /company/16-mile-solutions   16 Mile Solutions
# 46              /company/169-st             169 ST.
# 47         /company/170-systems         170 Systems
# 48              /company/17u-cn              17u.cn
# 49               /company/19pay               19pay
# 50                /company/1bib                1bib
# 51          /company/1c-company          1C Company
# 52           /company/1calendar           1calendar
# 53               /company/1cast               1Cast
# 54              /company/1click              1CLICK
# 55     /company/1cloudstar-asia          1CloudStar
# 56             /company/1d4-pty             1d4 Pty
# 57           /company/1daylater           1DayLater
# 58        /company/1daymakeover        1DayMakeover
# 59             /company/1docway             1DocWay
#                             ...                 ...
#
#                            homepage_url  category_code  funding_total_usd  \
# 0      http://www.canaldocredito.com.br        finance             750000
# 1                http://www.waywire.com           news            1750000
# 2                 http://enjoyandtv.com    games_video            4000000
# 3          http://www.rockyourpaper.org      education              40000
# 4         http://www.InTouchNetwork.com      ecommerce            1500000
# 5                      http://plusn.com       software             600000
# 6                    http://dotclub.com       software            7000000
# 7                 http://www.dotfox.com    advertising            4912394
# 8                    http://www.0-6.com            web            2000000
# 9                 http://www.0xdata.com      analytics            1700000
# 10              http://www.123listo.com      ecommerce              40000
# 11           http://www.1800dentist.com         health                  0
# 12               http://1800doctors.com         health            1750000
# 13            http://www.10-20media.com      ecommerce            2050000
# 14                 http://1000corks.com         search              40000
# 15           http://www.1000markets.com      ecommerce             500000
# 16         http://www.1000jobboersen.de            web                  0
# 17              http://1000memories.com            web            2535000
# 18           http://www.1000museums.com            web            4462651
# 19                 http://1001menus.com            web            1736910
# 20                 http://www.100du.com    hospitality            3000000
# 21                  http://www.100e.com      education            3000000
# 22               http://www.100plus.com      analytics            1250000
# 23              http://www.1010data.com       software           35000000
# 24     http://www.10alike.com/home#main    advertising                  0
# 25              http://10bestthings.com            web              50000
# 26     http://www.10secondsSoftware.com       software             100000
# 27           http://10xtechnologies.com        biotech            3000000
# 28                 http://10x10room.com       software              77500
# 29          http://www.11isolutions.com     enterprise            1800000
# 30               http://www.121cast.com         mobile             270000
# 31              http://www.121nexus.com       software             794000
# 32          http://www.1234enter.com.br      ecommerce             650267
# 33        http://www.123contactform.com      ecommerce                  0
# 34                 http://123people.com         search                  0
# 35  http://1248.io/index.php?page=index       software             378813
# 36             http://www.12Society.com      ecommerce                  0
# 37              http://www.1366tech.com  manufacturing           66450000
# 38               http://www.139shop.com      ecommerce                  0
# 39                   http://13thlab.com         mobile             700000
# 40                  http://140proof.com    advertising            5500000
# 41                   http://140fire.com    advertising             500000
# 42                   http://www.159.com       software            6204822
# 43                    http://15five.com       software            1200000
# 44              http://15minutesnow.com    games_video             200000
# 45                                    0       software             199957
# 46         http://www.junebugreview.com    games_video              50000
# 47            http://www.170systems.com       software           14000000
# 48                    http://www.17u.cn         travel           84691914
# 49              http://www.19pay.com.cn        finance            9477280
# 50                  http://www.1bib.com            web                  0
# 51                     http://1c.ru/eng       software          200000000
# 52                 http://1calendar.com      education              40000
# 53                 http://www.1cast.com           news                  0
# 54                     http://1click.io         mobile                  0
# 55            http://www.1CloudStar.com     enterprise                  0
# 56      http://www.immortaloutdoors.com              0              40000
# 57                 http://1daylater.com            web              43812
# 58          http://www.1daymakeover.com      ecommerce              50000
# 59                   http://1docway.com          other                  0
#                                     ...            ...                ...
#
#        status country_code state_code             region            city  \
# 0   operating          BRA          0     Belo Horizonte  Belo Horizonte
# 1    acquired          USA         NY           New York        New York
# 2   operating          USA         CA        Los Angeles     Los Angeles
# 3   operating          EST          0            Tallinn         Tallinn
# 4   operating          GBR          0             London          London
# 5   operating          USA         NY           New York        New York
# 6   operating          USA         FL    Fort Lauderdale    Oakland Park
# 7      closed          ARG          0       Buenos Aires    Buenos Aires
# 8   operating            0          0            unknown               0
# 9   operating          USA         CA             SF Bay   Mountain View
# 10  operating          CHL          0         Las Condes      Las Condes
# 11  operating          USA         CA        Los Angeles     Los Angeles
# 12  operating          USA         NJ             Iselin          Iselin
# 13  operating          USA         MD      Washington DC        Woodbine
# 14  operating          USA         OR           Portland     Lake Oswego
# 15   acquired            0          0            unknown               0
# 16  operating          DEU          0    Germany - Other               0
# 17   acquired          USA         CA             SF Bay   San Francisco
# 18  operating          USA         WA            Seattle        Bellevue
# 19  operating          FRA          0              Paris           Paris
# 20  operating            0          0            unknown               0
# 21  operating          CHN          0            Beijing         Beijing
# 22   acquired          USA         CA             SF Bay   San Francisco
# 23  operating          USA         NY           New York        New York
# 24  operating          CAN          0            Toronto         Toronto
# 25     closed          USA         OH          Cleveland       Cleveland
# 26  operating          AUS          0             Sydney          Sydney
# 27  operating          USA         CA             SF Bay         Oakland
# 28  operating          USA         MA             Boston       Lexington
# 29     closed          USA         AL         Huntsville      Huntsville
# 30  operating          AUS          0          Melbourne       Melbourne
# 31  operating          USA         RI         Providence      Providence
# 32  operating          BRA          0     Brazil - Other               0
# 33  operating          ROM          0          Timisoara       Timisoara
# 34   acquired          AUT          0             Vienna          Vienna
# 35  operating          GBR          0             London       Cambridge
# 36   acquired          USA         CA        Los Angeles  West Hollywood
# 37  operating          USA         MA             Boston         Bedford
# 38  operating          CHN          0      China - Other               0
# 39  operating          SWE          0          Stockholm       Stockholm
# 40  operating          USA         CA             SF Bay   San Francisco
# 41  operating          USA         CA        Los Angeles    Santa Monica
# 42  operating          CHN          0      China - Other               0
# 43  operating          USA         CA             SF Bay   San Francisco
# 44  operating            0          0            unknown               0
# 45  operating          USA         WA            Seattle         Seattle
# 46     closed          USA         FL            Orlando       Lake Mary
# 47   acquired          USA         MA             Boston         Bedford
# 48  operating          HKG          0  Hong Kong - Other               0
# 49  operating          CHN          0            Beijing         Beijing
# 50     closed          CHN          0          Guangzhou       Guangzhou
# 51  operating          RUS          0             Moscow          Moscow
# 52  operating          DNK          0                DNK      Copenhagen
# 53     closed          USA         WA            Seattle        Kirkland
# 54  operating          IND          0          Bangalore       Bangalore
# 55  operating          SGP          0          Singapore       Singapore
# 56  operating          AUS          0  Australia - Other               0
# 57  operating            0          0            unknown               0
# 58     closed          USA         CA        Los Angeles       Santa Ana
# 59  operating          USA         PA       Philadelphia    Philadelphia
#           ...          ...        ...                ...             ...
#
#     funding_rounds founded_at founded_month founded_quarter  founded_year  \
# 0                1          0             0               0             0
# 1                1     6/1/12      2012-06          2012-Q2          2012
# 2                2          0             0               0             0
# 3                1   10/26/12      2012-10          2012-Q4          2012
# 4                1     4/1/11      2011-04          2011-Q2          2011
# 5                1     1/1/12      2012-01          2012-Q1          2012
# 6                1   10/10/11      2011-10          2011-Q4          2011
# 7                1          0             0               0             0
# 8                1     1/1/07      2007-01          2007-Q1          2007
# 9                1     1/1/11      2011-01          2011-Q1          2011
# 10               1     1/1/12      2012-01          2012-Q1          2012
# 11               1     1/1/86      1986-01          1986-Q1          1986
# 12               1     1/1/84      1984-01          1984-Q1          1984
# 13               4     1/1/01      2001-01          2001-Q1          2001
# 14               1     1/1/08      2008-01          2008-Q1          2008
# 15               1     1/1/09      2009-01          2009-Q1          2009
# 16               1          0             0               0             0
# 17               2     7/1/10      2010-07          2010-Q3          2010
# 18               4     1/1/08      2008-01          2008-Q1          2008
# 19               1   11/20/10      2010-11          2010-Q4          2010
# 20               2          0             0               0             0
# 21               1          0             0               0             0
# 22               2    9/16/11      2011-09          2011-Q3          2011
# 23               1     1/1/00      2000-01          2000-Q1          2000
# 24               1     3/3/12      2012-03          2012-Q1          2012
# 25               1     4/1/09      2009-04          2009-Q2          2009
# 26               1     7/1/09      2009-07          2009-Q3          2009
# 27               1     1/1/12      2012-01          2012-Q1          2012
# 28               1     1/1/10      2010-01          2010-Q1          2010
# 29               1          0             0               0             0
# 30               2     2/1/12      2012-02          2012-Q1          2012
# 31               6    10/7/11      2011-10          2011-Q4          2011
# 32               2     1/1/12      2012-01          2012-Q1          2012
# 33               1     1/1/08      2008-01          2008-Q1          2008
# 34               1     1/1/07      2007-01          2007-Q1          2007
# 35               1     1/1/13      2013-01          2013-Q1          2013
# 36               1     1/1/12      2012-01          2012-Q1          2012
# 37               8     1/1/07      2007-01          2007-Q1          2007
# 38               1          0             0               0             0
# 39               1     1/1/10      2010-01          2010-Q1          2010
# 40               2    1/11/10      2010-01          2010-Q1          2010
# 41               1     1/1/10      2010-01          2010-Q1          2010
# 42               2          0             0               0             0
# 43               2     5/1/11      2011-05          2011-Q2          2011
# 44               1    4/19/11      2011-04          2011-Q2          2011
# 45               1     1/1/06      2006-01          2006-Q1          2006
# 46               1    5/15/09      2009-05          2009-Q2          2009
# 47               1     1/1/90      1990-01          1990-Q1          1990
# 48               3     1/1/04      2004-01          2004-Q1          2004
# 49               3     1/1/05      2005-01          2005-Q1          2005
# 50               1     1/1/06      2006-01          2006-Q1          2006
# 51               1     1/1/91      1991-01          1991-Q1          1991
# 52               1    1/19/09      2009-01          2009-Q1          2009
# 53               1     6/1/06      2006-06          2006-Q2          2006
# 54               1    11/1/12      2012-11          2012-Q4          2012
# 55               1     1/1/12      2012-01          2012-Q1          2012
# 56               1          0             0               0             0
# 57               2    8/26/09      2009-08          2009-Q3          2009
# 58               1    6/30/08      2008-06          2008-Q2          2008
# 59               1     2/1/11      2011-02          2011-Q1          2011
#                ...        ...           ...             ...           ...
#
#    first_funding_at last_funding_at last_milestone_at
# 0            1/1/10          1/1/10                 0
# 1           6/30/12         6/30/12          10/17/13
# 2            6/4/10         9/23/10                 0
# 3            8/9/12          8/9/12                 0
# 4            4/1/11          4/1/11          11/15/13
# 5           8/29/12         8/29/12                 0
# 6           5/31/13         5/31/13                 0
# 7           1/16/07         1/16/07            7/1/08
# 8           3/19/08         3/19/08                 0
# 9            1/3/13          1/3/13            1/1/12
# 10          2/18/13         2/18/13                 0
# 11          8/19/10         8/19/10           8/19/10
# 12           3/2/11          3/2/11                 0
# 13          6/18/09        12/28/11                 0
# 14          8/23/11         8/23/11                 0
# 15          5/15/09         5/15/09           9/21/10
# 16          9/16/11         9/16/11                 0
# 17           1/1/10         2/16/11            7/4/13
# 18         10/14/09         1/15/14           2/16/13
# 19         11/13/13        11/13/13            1/1/13
# 20           1/7/08         8/13/10                 0
# 21           1/1/06          1/1/06                 0
# 22          11/2/11        11/30/11           2/27/13
# 23           3/8/10          3/8/10            1/1/12
# 24           1/1/13          1/1/13           1/17/13
# 25           4/1/09          4/1/09                 0
# 26           7/1/10          7/1/10                 0
# 27          11/7/12         11/7/12                 0
# 28         10/12/11        10/12/11                 0
# 29          3/22/11         3/22/11                 0
# 30           5/1/12        11/13/12          11/15/12
# 31           2/6/12          1/1/14           4/27/12
# 32           9/1/12        11/22/13                 0
# 33           1/1/10          1/1/10            1/1/11
# 34           1/1/08          1/1/08            4/4/11
# 35          3/18/14         3/18/14                 0
# 36           4/5/12          4/5/12            7/3/13
# 37          3/27/08        12/12/13           6/17/11
# 38           2/1/07          2/1/07                 0
# 39          6/15/12         6/15/12            6/1/12
# 40           7/1/09         4/28/11           1/24/13
# 41           5/5/10          5/5/10           2/24/11
# 42           2/1/08          3/1/11                 0
# 43           1/1/12         1/15/13           9/19/13
# 44          5/10/11         5/10/11                 0
# 45          6/11/09         6/11/09                 0
# 46           6/1/09          6/1/09            5/1/09
# 47          4/16/02         4/16/02            1/1/03
# 48           1/1/08          2/1/14                 0
# 49           1/1/06          7/1/13                 0
# 50           2/7/08          2/7/08                 0
# 51          10/3/11         10/3/11           4/11/12
# 52           4/4/08          4/4/08            1/1/07
# 53          8/12/08         8/12/08            6/1/09
# 54          1/26/14         1/26/14                 0
# 55           8/1/13          8/1/13            1/1/14
# 56          4/11/12         4/11/12                 0
# 57           5/1/09         10/1/09           8/26/09
# 58          6/30/08         6/30/08                 0
# 59          8/10/11         8/10/11                 0
#                 ...             ...               ...
#
# [37875 rows x 18 columns]

# %%
acquisitions = pd.read_csv('/Users/Work/Documents/CS249/project/crunchbase/Data/acquisitions.csv')
acquisitions=acquisitions.dropna(how='all')
acquisitions.head()
# Out:
#               company_permalink         company_name company_category_code  \
# 0              /company/waywire             #waywire                  news
# 1        /company/fluff-friends       (fluff)Friends                   NaN
# 2          /company/co-internet                  .CO                   web
# 3      /company/0958572-b-c-ltd    0958572 B.C. Ltd.                   NaN
# 4  /company/1-nation-technology  1 Nation Technology                   NaN
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY       New York     New York
# 1                  NaN                NaN        unknown          NaN
# 2                  USA                 FL          Miami        Miami
# 3                  NaN                NaN        unknown          NaN
# 4                  NaN                NaN        unknown          NaN
#
#                                   acquirer_permalink  \
# 0                                   /company/magnify
# 1                     /company/social-gaming-network
# 2                                   /company/neustar
# 3  /company/atlas-intellectual-property-managemen...
# 4                                    /company/vology
#
#                                 acquirer_name acquirer_category_code  \
# 0                                     Magnify            games_video
# 1                       Social Gaming Network            games_video
# 2                                     Neustar       public_relations
# 3  ATLAS Intellectual Property Management Co.                finance
# 4                                      Vology                  other
#
#   acquirer_country_code acquirer_state_code acquirer_region  acquirer_city  \
# 0                   USA                  NY        New York       New York
# 1                   USA                  CA     Los Angeles  Beverly Hills
# 2                   USA                  VA   Washington DC       Sterling
# 3                   USA                  WA         Seattle        Seattle
# 4                   NaN                 NaN         unknown            NaN
#
#   acquired_at acquired_month acquired_quarter  acquired_year  price_amount  \
# 0    10/17/13        2013-10          2013-Q4           2013           NaN
# 1     9/16/08        2008-09          2008-Q3           2008           NaN
# 2     3/20/14        2014-03          2014-Q1           2014   109,000,000
# 3      2/2/12        2012-02          2012-Q1           2012     9,000,000
# 4      1/1/06        2006-01          2006-Q1           2006           NaN
#
#   price_currency_code
# 0                 USD
# 1                 USD
# 2                 USD
# 3                 USD
# 4                 USD
#
# [5 rows x 20 columns]

# %%
additions = pd.read_csv('/Users/Work/Documents/CS249/project/crunchbase/Data/additions.csv')
additions=additions.dropna(axis=1, how='all')
additions.head()
# Out:
#                content month_str quarter_str  year_str  value
# 0  Profiles: Companies   2007-05     2007-Q2      2007      9
# 1  Profiles: Companies   2007-06     2007-Q2      2007     59
# 2  Profiles: Companies   2007-07     2007-Q3      2007    168
# 3  Profiles: Companies   2007-08     2007-Q3      2007    406
# 4  Profiles: Companies   2007-09     2007-Q3      2007    183
#
# [5 rows x 5 columns]

# %%
investments = pd.read_csv('/Users/Work/Documents/CS249/project/crunchbase/Data/investments.csv')
investments=investments.dropna(how='all')
investments
# Out:
# /Users/Work/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                    company_permalink             company_name  \
# 0        /company/tokita-investments       Tokita Investments
# 1                  /company/advercar                 AdverCar
# 2                /company/launchgram               LaunchGram
# 3                      /company/utap                     uTaP
# 4                  /company/zoopshop                 ZoopShop
# 5                  /company/efuneral                 eFuneral
# 6                     /company/tackk                    Tackk
# 7                  /company/acclaimd                 Acclaimd
# 8                   /company/acceptd                  Acceptd
# 9                    /company/prized                   Prized
# 10                   /company/imagry                   Imagry
# 11                   /company/moveez                   MoveEZ
# 12            /company/connecttohome            ConnectToHome
# 13  /company/panopticon-laboratories  Panopticon Laboratories
# 14              /company/fly-apparel              Fly Apparel
# 15                      /company/oye                     OYE!
# 16                   /company/leapin      LEAPIN Digital Keys
# 17                /company/last-size                Last Size
# 18                /company/stockleap                Stockleap
# 19                /company/morphcard                morphCARD
# 20        /company/oneexchangestreet        Oneexchangestreet
# 21             /company/rooftop-down             Rooftop Down
# 22                 /company/mondokio                 Mondokio
# 23                 /company/whodoyou                 whodoyou
# 24            /company/nival-network                    Nival
# 25                  /company/startme                  StartMe
# 26                   /company/vennli                   Vennli
# 27              /company/readfy-gmbh                   readfy
# 28                 /company/toviefor                 ToVieFor
# 29                    /company/ispye                    iSpye
# 30               /company/aentropico               Aentropico
# 31                 /company/ohk-labs                 OHK Labs
# 32                    /company/latto                    LATTO
# 33                    /company/latto                    LATTO
# 34                  /company/airvend                  AIRVEND
# 35                 /company/yikuaiqu                 Yikuaiqu
# 36                  /company/blokify                  Blokify
# 37                  /company/faraday                  Faraday
# 38                      /company/msi                      MSI
# 39        /company/ecovative-designs         Ecovative Design
# 40                   /company/lovely                   Lovely
# 41            /company/myfairpartner            myFairPartner
# 42         /company/birthdayslam-com            Birthday Slam
# 43             /company/peertransfer             peerTransfer
# 44           /company/51intern-com-2   51intern.com �����_�_�
# 45                 /company/buzzoole                 Buzzoole
# 46               /company/intertwine               Intertwine
# 47               /company/kartrocket               KartRocket
# 48                     /company/viss                     Viss
# 49                /company/sfilatino                sfilatino
# 50                 /company/spotdock                 spotdock
# 51                     /company/ag-p                     AG&P
# 52          /company/azure-solutions          Azure Solutions
# 53                   /company/fisker        Fisker Automotive
# 54                   /company/fisker        Fisker Automotive
# 55           /company/metroflats-com           MetroFlats.com
# 56              /company/sportsetter              SportSetter
# 57                    /company/peerz                    Peerz
# 58                 /company/mesocoat                 MesoCoat
# 59                /company/trilliant                Trilliant
#                                  ...                      ...
#
#    company_category_code company_country_code company_state_code  \
# 0             consulting                  JPN                NaN
# 1            advertising                  USA                 CA
# 2                   news                  USA                 CA
# 3              messaging                  USA                 OH
# 4               software                  USA                 OH
# 5                    web                  USA                 OH
# 6                    web                  USA                 OH
# 7              analytics                  USA                 OH
# 8               software                  USA                 OH
# 9            games_video                  USA                NaN
# 10              software                  USA                 OH
# 11                   web                  USA                 OH
# 12                 other                  USA                 OH
# 13              security                  NaN                NaN
# 14               fashion                  USA                 OH
# 15             analytics                  USA                 OH
# 16                mobile                  AUS                NaN
# 17                   NaN                  USA                 OH
# 18                   NaN                  USA                 OH
# 19              software                  USA                 OH
# 20                   NaN                  USA                 OH
# 21                   NaN                  USA                 OH
# 22                   NaN                  NaN                NaN
# 23                   web                  ISR                NaN
# 24           games_video                  RUS                NaN
# 25               finance                  ZAF                NaN
# 26              software                  USA                 IN
# 27                mobile                  DEU                NaN
# 28             ecommerce                  USA                 NY
# 29                mobile                  GBR                NaN
# 30             analytics                  BRA                NaN
# 31                sports                  USA                 FL
# 32            enterprise                  ISR                NaN
# 33            enterprise                  ISR                NaN
# 34              software                  USA                 UT
# 35                travel                  CHN                NaN
# 36           games_video                  USA                 NY
# 37              software                  NaN                NaN
# 38              hardware                  USA                 FL
# 39             cleantech                  USA                 NY
# 40           real_estate                  USA                 CA
# 41            consulting                  GBR                NaN
# 42                health                  CAN                NaN
# 43               finance                  USA                 MA
# 44                social                  CHN                NaN
# 45           advertising                  ITA                NaN
# 46                   web                  ITA                NaN
# 47             ecommerce                  IND                NaN
# 48             ecommerce                  HKG                NaN
# 49             ecommerce                  ITA                NaN
# 50                   web                  USA                 NY
# 51             cleantech                  PHL                NaN
# 52              software                  GBR                NaN
# 53            automotive                  USA                 CA
# 54            automotive                  USA                 CA
# 55                travel                  USA                 NJ
# 56                health                  FIN                NaN
# 57                   web                  NLD                NaN
# 58              nanotech                  USA                 OH
# 59              hardware                  USA                 CA
#                      ...                  ...                ...
#
#            company_region              company_city  \
# 0                     TBD               Okinawa Ken
# 1                  SF Bay             San Francisco
# 2                  SF Bay             Mountain View
# 3                Columbus                  Columbus
# 4                Columbus                  columbus
# 5               Cleveland                 Cleveland
# 6               Cleveland                 Cleveland
# 7                Columbus                  Columbus
# 8                Columbus                    Dublin
# 9   United States - Other                       NaN
# 10               Columbus                  Columbus
# 11               Columbus                  Columbus
# 12           Ohio - Other                       NaN
# 13                unknown                       NaN
# 14               Columbus                  Columbus
# 15               Columbus                  Columbus
# 16             Gold Coast                Gold Coast
# 17               Columbus                  Columbus
# 18               Columbus                  Columbus
# 19               Columbus                  Columbus
# 20               Columbus                  Columbus
# 21               Columbus                  Columbus
# 22                unknown                       NaN
# 23         Israel - Other                       NaN
# 24                 Moscow                    Moscow
# 25                Midrand                   Midrand
# 26             South Bend                South Bend
# 27            Duesseldorf               Duesseldorf
# 28               New York                  New York
# 29                Glasgow                   Glasgow
# 30         Rio de Janeiro            Rio de Janeiro
# 31             Palm Beach                Boca Raton
# 32               Tel Aviv                  Tel Aviv
# 33               Tel Aviv                  Tel Aviv
# 34         Salt Lake City                     Provo
# 35              Guangzhou                 Guangzhou
# 36               New York                  New York
# 37                unknown                       NaN
# 38             Palm Beach                Boca Raton
# 39           Green Island              Green Island
# 40                 SF Bay             San Francisco
# 41                 London                    London
# 42                Toronto                   Toronto
# 43                 Boston                    Boston
# 44         Putuo District  Putuo District, Shanghai
# 45                 Naples                    Naples
# 46                    TBD                  Fisciano
# 47              New Delhi                 New Delhi
# 48             Quarry Bay                Quarry Bay
# 49                 Milano                    milano
# 50               New York                       NYC
# 51                    TBD           Muntinlupa City
# 52                 London                    London
# 53            Los Angeles                    Irvine
# 54            Los Angeles                    Irvine
# 55            Cedar Grove               Cedar Grove
# 56               Helsinki                  Helsinki
# 57              Amsterdam                 Amsterdam
# 58              Cleveland                    Euclid
# 59                 SF Bay              Redwood City
#                       ...                       ...
#
#                                    investor_permalink  \
# 0                                 /company/01startups
# 1                          /company/1-800-flowers-com
# 2                                /company/10xelerator
# 3                                /company/10xelerator
# 4                                /company/10xelerator
# 5                                /company/10xelerator
# 6                                /company/10xelerator
# 7                                /company/10xelerator
# 8                                /company/10xelerator
# 9                                /company/10xelerator
# 10                               /company/10xelerator
# 11                               /company/10xelerator
# 12                               /company/10xelerator
# 13                               /company/10xelerator
# 14                               /company/10xelerator
# 15                               /company/10xelerator
# 16                               /company/10xelerator
# 17                               /company/10xelerator
# 18                               /company/10xelerator
# 19                               /company/10xelerator
# 20                               /company/10xelerator
# 21                               /company/10xelerator
# 22                               /company/10xelerator
# 23                               /company/18-partners
# 24                                /company/1c-company
# 25                        /company/1st-media-services
# 26                           /company/1st-source-bank
# 27                              /company/1stmover-org
# 28  /company/2010-nyu-stern-business-plan-competition
# 29                    /company/20-20-multimedia-group
# 30                                     /company/21212
# 31                           /company/22hundred-group
# 32                                  /company/2bangles
# 33                                  /company/2bangles
# 34                        /company/365-retail-markets
# 35                                      /company/36kr
# 36                                /company/3d-systems
# 37                                  /company/3degrees
# 38                                        /company/3m
# 39                                /company/3m-company
# 40                                     /company/3taps
# 41                             /company/3u-holding-ag
# 42                                /company/3w-capital
# 43                                  /company/500-hats
# 44                       /company/51intern-consulting
# 45                                    /company/56cube
# 46                                    /company/56cube
# 47                                 /company/5ideas-in
# 48                            /company/8-plus-holding
# 49                             /company/99-fahrenheit
# 50                               /company/9mmedia-llc
# 51                     /company/a-soriano-corporation
# 52                          /company/a-g-edwards-sons
# 53                               /company/a123systems
# 54                               /company/a123systems
# 55                            /company/aa-investments
# 56                     /company/aalto-start-up-center
# 57                               /company/aamigoo-com
# 58                                /company/abakan-inc
# 59                                       /company/abb
#                                                   ...
#
#                                investor_name investor_category_code  \
# 0                                 01Startups                    NaN
# 1                          1-800-FLOWERS.COM              ecommerce
# 2                                10Xelerator                finance
# 3                                10Xelerator                finance
# 4                                10Xelerator                finance
# 5                                10Xelerator                finance
# 6                                10Xelerator                finance
# 7                                10Xelerator                finance
# 8                                10Xelerator                finance
# 9                                10Xelerator                finance
# 10                               10Xelerator                finance
# 11                               10Xelerator                finance
# 12                               10Xelerator                finance
# 13                               10Xelerator                finance
# 14                               10Xelerator                finance
# 15                               10Xelerator                finance
# 16                               10Xelerator                finance
# 17                               10Xelerator                finance
# 18                               10Xelerator                finance
# 19                               10Xelerator                finance
# 20                               10Xelerator                finance
# 21                               10Xelerator                finance
# 22                               10Xelerator                finance
# 23                               18 Partners                    NaN
# 24                                1C Company               software
# 25                        1st Media services                    NaN
# 26                           1st Source Bank                    NaN
# 27                              1stMover.org                    NaN
# 28  2010 NYU Stern Business Plan Competition                    NaN
# 29                    20:20 Multimedia Group                    NaN
# 30                                   1/27/58                    web
# 31                           22Hundred Group                    NaN
# 32                                  2BAngles                    NaN
# 33                                  2BAngles                    NaN
# 34                        365 Retail Markets               software
# 35                                      36Kr                    NaN
# 36                                3D Systems               software
# 37                                  3Degrees              cleantech
# 38                                        3M             enterprise
# 39                                3M Company                    NaN
# 40                                     3taps                    web
# 41                             3U HOLDING AG                    NaN
# 42                                3W Capital                    NaN
# 43                                  500 Hats                    NaN
# 44                       51intern Consulting                    NaN
# 45                                    56CUBE                  other
# 46                                    56CUBE                  other
# 47                                 5ideas.in                  other
# 48                            8 Plus Holding                    NaN
# 49                             99 Fahrenheit                finance
# 50                              9mmedia, LLC                    NaN
# 51                    A. Soriano Corporation                finance
# 52                       A.G. Edwards & Sons                    NaN
# 53                              A123 Systems                 mobile
# 54                              A123 Systems                 mobile
# 55                            AA Investments                    NaN
# 56                     Aalto Start Up Center                    NaN
# 57                               AamigoO.com                    NaN
# 58                                    Abakan              cleantech
# 59                                       ABB              cleantech
#                                          ...                    ...
#
#    investor_country_code investor_state_code  investor_region   investor_city  \
# 0                    NaN                 NaN          unknown             NaN
# 1                    USA                  NY         New York        New York
# 2                    USA                  OH         Columbus        Columbus
# 3                    USA                  OH         Columbus        Columbus
# 4                    USA                  OH         Columbus        Columbus
# 5                    USA                  OH         Columbus        Columbus
# 6                    USA                  OH         Columbus        Columbus
# 7                    USA                  OH         Columbus        Columbus
# 8                    USA                  OH         Columbus        Columbus
# 9                    USA                  OH         Columbus        Columbus
# 10                   USA                  OH         Columbus        Columbus
# 11                   USA                  OH         Columbus        Columbus
# 12                   USA                  OH         Columbus        Columbus
# 13                   USA                  OH         Columbus        Columbus
# 14                   USA                  OH         Columbus        Columbus
# 15                   USA                  OH         Columbus        Columbus
# 16                   USA                  OH         Columbus        Columbus
# 17                   USA                  OH         Columbus        Columbus
# 18                   USA                  OH         Columbus        Columbus
# 19                   USA                  OH         Columbus        Columbus
# 20                   USA                  OH         Columbus        Columbus
# 21                   USA                  OH         Columbus        Columbus
# 22                   USA                  OH         Columbus        Columbus
# 23                   NaN                 NaN          unknown             NaN
# 24                   RUS                 NaN           Moscow          Moscow
# 25                   NaN                 NaN          unknown             NaN
# 26                   NaN                 NaN          unknown             NaN
# 27                   NaN                 NaN          unknown             NaN
# 28                   NaN                 NaN          unknown             NaN
# 29                   NaN                 NaN          unknown             NaN
# 30                   BRA                 NaN   Rio de Janeiro  Rio de Janeiro
# 31                   NaN                 NaN          unknown             NaN
# 32                   NaN                 NaN          unknown             NaN
# 33                   NaN                 NaN          unknown             NaN
# 34                   USA                  MI          Detroit            Troy
# 35                   CHN                 NaN          Beijing         Beijing
# 36                   USA                  SC        Rock Hill       Rock Hill
# 37                   USA                  CA           SF Bay   San Francisco
# 38                   USA                  MN      Minneapolis         St Paul
# 39                   NaN                 NaN          unknown             NaN
# 40                   USA                  CA           SF Bay   San Francisco
# 41                   NaN                 NaN          unknown             NaN
# 42                   NaN                 NaN          unknown             NaN
# 43                   USA                  CA           SF Bay       Palo Alto
# 44                   NaN                 NaN          unknown             NaN
# 45                   ITA                 NaN         Fisciano   Fisciano (SA)
# 46                   ITA                 NaN         Fisciano   Fisciano (SA)
# 47                   IND                 NaN          Gurgaon         Gurgaon
# 48                   NaN                 NaN          unknown             NaN
# 49                   ITA                 NaN           Milano          Milano
# 50                   NaN                 NaN          unknown             NaN
# 51                   PHL                 NaN           Makati          Makati
# 52                   USA                  MO      Saint Louis       St. Louis
# 53                   USA                  MA           Boston     Westborough
# 54                   USA                  MA           Boston     Westborough
# 55                   BMU                 NaN  Bermuda - Other             NaN
# 56                   NaN                 NaN          unknown             NaN
# 57                   NaN                 NaN          unknown             NaN
# 58                   USA                  FL            Miami           Miami
# 59                   CHE                 NaN           Zurich          Zurich
#                      ...                 ...              ...             ...
#
#    funding_round_type funded_at funded_month funded_quarter  funded_year  \
# 0               angel   9/26/13      2013-09        2013-Q3         2013
# 1            series-a  10/30/12      2012-10        2012-Q4         2012
# 2               other   1/23/12      2012-01        2012-Q1         2012
# 3               other    1/1/12      2012-01        2012-Q1         2012
# 4               angel   2/15/12      2012-02        2012-Q1         2012
# 5               other    9/8/11      2011-09        2011-Q3         2011
# 6               angel   4/10/12      2012-04        2012-Q2         2012
# 7               angel    6/1/12      2012-06        2012-Q2         2012
# 8               angel    6/1/11      2011-06        2011-Q2         2011
# 9               angel   8/10/13      2013-08        2013-Q3         2013
# 10              angel    9/1/13      2013-09        2013-Q3         2013
# 11              other   9/16/13      2013-09        2013-Q3         2013
# 12              other   9/19/13      2013-09        2013-Q3         2013
# 13              angel    9/4/13      2013-09        2013-Q3         2013
# 14              angel    9/1/13      2013-09        2013-Q3         2013
# 15              angel    9/4/13      2013-09        2013-Q3         2013
# 16              angel   8/16/13      2013-08        2013-Q3         2013
# 17              angel   8/16/13      2013-08        2013-Q3         2013
# 18              angel   8/16/13      2013-08        2013-Q3         2013
# 19              angel   4/10/12      2012-04        2012-Q2         2012
# 20              angel   4/10/12      2012-04        2012-Q2         2012
# 21              angel   4/10/12      2012-04        2012-Q2         2012
# 22              angel  10/25/11      2011-10        2011-Q4         2011
# 23              angel    1/1/14      2014-01        2014-Q1         2014
# 24            venture   3/17/10      2010-03        2010-Q1         2010
# 25              other   10/1/11      2011-10        2011-Q4         2011
# 26              angel    3/5/14      2014-03        2014-Q1         2014
# 27              angel    7/1/13      2013-07        2013-Q3         2013
# 28              angel    4/1/10      2010-04        2010-Q2         2010
# 29     private-equity   9/26/12      2012-09        2012-Q3         2012
# 30              angel   3/13/13      2013-03        2013-Q1         2013
# 31              angel    9/1/11      2011-09        2011-Q3         2011
# 32           series-a    2/1/11      2011-02        2011-Q1         2011
# 33           series-b   7/31/13      2013-07        2013-Q3         2013
# 34              angel    1/2/14      2014-01        2014-Q1         2014
# 35           series-a   1/27/14      2014-01        2014-Q1         2014
# 36              angel    9/1/13      2013-09        2013-Q3         2013
# 37           series-a   3/20/14      2014-03        2014-Q1         2014
# 38            venture    3/3/14      2014-03        2014-Q1         2014
# 39            venture   11/8/13      2013-11        2013-Q4         2013
# 40           series-a   10/1/12      2012-10        2012-Q4         2012
# 41              angel    1/1/09      2009-01        2009-Q1         2009
# 42              angel   10/1/10      2010-10        2010-Q4         2010
# 43              angel  10/28/10      2010-10        2010-Q4         2010
# 44              angel   11/1/10      2010-11        2010-Q4         2010
# 45              angel  11/12/13      2013-11        2013-Q4         2013
# 46            venture   12/5/13      2013-12        2013-Q4         2013
# 47              angel   7/23/13      2013-07        2013-Q3         2013
# 48              angel   5/20/13      2013-05        2013-Q2         2013
# 49              angel   2/20/12      2012-02        2012-Q1         2012
# 50              angel   1/10/12      2012-01        2012-Q1         2012
# 51          series-c+    7/2/13      2013-07        2013-Q3         2013
# 52            venture   6/16/05      2005-06        2005-Q2         2005
# 53     private-equity    5/1/10      2010-05        2010-Q2         2010
# 54     private-equity   2/22/11      2011-02        2011-Q1         2011
# 55              angel   8/18/10      2010-08        2010-Q3         2010
# 56              angel    6/1/12      2012-06        2012-Q2         2012
# 57              angel   1/14/10      2010-01        2010-Q1         2010
# 58            venture  12/14/09      2009-12        2009-Q4         2009
# 59           series-b   7/15/10      2010-07        2010-Q3         2010
#                   ...       ...          ...            ...          ...
#
#    raised_amount_usd
# 0              5,000
# 1          2,000,000
# 2             20,000
# 3             20,000
# 4             20,000
# 5             20,000
# 6                NaN
# 7             20,000
# 8             20,000
# 9             20,000
# 10            20,000
# 11            20,000
# 12            20,000
# 13            20,000
# 14            20,000
# 15            20,000
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23           900,000
# 24         7,000,000
# 25            50,000
# 26         1,300,000
# 27               NaN
# 28            75,000
# 29               NaN
# 30            25,000
# 31           100,000
# 32        11,000,000
# 33         4,000,000
# 34         1,200,000
# 35               NaN
# 36           600,000
# 37           880,000
# 38               NaN
# 39        14,000,000
# 40         2,000,000
# 41           620,969
# 42           100,000
# 43         1,100,000
# 44               NaN
# 45           231,588
# 46           141,526
# 47               NaN
# 48               NaN
# 49           100,000
# 50           600,000
# 51        53,000,000
# 52        15,000,000
# 53       189,000,000
# 54       150,000,000
# 55               NaN
# 56            67,000
# 57           144,860
# 58               NaN
# 59       106,000,000
#                  ...
#
# [90283 rows x 20 columns]

# %%
rounds = pd.read_csv('/Users/Work/Documents/CS249/project/crunchbase/Data/rounds.csv')
rounds=rounds.dropna(axis=1, how='all')
rounds.head()
# Out:
#             company_permalink        company_name company_category_code  \
# 0   /company/canal-do-credito    Canal do Credito               finance
# 1            /company/waywire            #waywire                  news
# 2  /company/tv-communications  &TV Communications           games_video
# 3  /company/tv-communications  &TV Communications           games_video
# 4  /company/rock-your-paper-2   'Rock' Your Paper             education
#
#   company_country_code company_state_code  company_region    company_city  \
# 0                  BRA                NaN  Belo Horizonte  Belo Horizonte
# 1                  USA                 NY        New York        New York
# 2                  USA                 CA     Los Angeles     Los Angeles
# 3                  USA                 CA     Los Angeles     Los Angeles
# 4                  EST                NaN         Tallinn         Tallinn
#
#   funding_round_type funded_at funded_month funded_quarter  funded_year  \
# 0           series-a    1/1/10      2010-01        2010-Q1         2010
# 1           series-a   6/30/12      2012-06        2012-Q2         2012
# 2            venture    6/4/10      2010-06        2010-Q2         2010
# 3            venture   9/23/10      2010-09        2010-Q3         2010
# 4              angel    8/9/12      2012-08        2012-Q3         2012
#
#   raised_amount_usd
# 0           750,000
# 1         1,750,000
# 2         1,000,000
# 3         3,000,000
# 4            40,000
#
# [5 rows x 13 columns]

# %%
print(companies.columns.values.tolist())
print(additions.columns.values.tolist())
print(acquisitions.columns.values.tolist())
print(investments.columns.values.tolist())
print(rounds.columns.values.tolist())
# Out:
# ['permalink', 'name', 'homepage_url', 'category_code', 'funding_total_usd', 'status', 'country_code', 'state_code', 'region', 'city', 'funding_rounds', 'founded_at', 'founded_month', 'founded_quarter', 'founded_year', 'first_funding_at', 'last_funding_at', 'last_milestone_at']
# ['content', 'month_str', 'quarter_str', 'year_str', 'value']
# ['company_permalink', 'company_name', 'company_category_code', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'acquirer_permalink', 'acquirer_name', 'acquirer_category_code', 'acquirer_country_code', 'acquirer_state_code', 'acquirer_region', 'acquirer_city', 'acquired_at', 'acquired_month', 'acquired_quarter', 'acquired_year', ' price_amount', 'price_currency_code']
# ['company_permalink', 'company_name', 'company_category_code', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'investor_permalink', 'investor_name', 'investor_category_code', 'investor_country_code', 'investor_state_code', 'investor_region', 'investor_city', 'funding_round_type', 'funded_at', 'funded_month', 'funded_quarter', 'funded_year', 'raised_amount_usd']
# ['company_permalink', 'company_name', 'company_category_code', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'funding_round_type', 'funded_at', 'funded_month', 'funded_quarter', 'funded_year', 'raised_amount_usd']

# %%
# Get "Set2" colors from ColorBrewer (all colorbrewer scales: http://bl.ocks.org/mbostock/5577023)
set2 = brewer2mpl.get_map('Set2', 'qualitative', 8).mpl_colors
set3 = brewer2mpl.get_map('Set3', 'qualitative', 8).mpl_colors

category_name_counts=companies.groupby('category_code').count()[['name']]
category_name_counts.plot(kind='bar',color=[set3[x] for x in range(4)], grid= False, figsize=(20, 6), edgecolor='w', title="Frequency of Categories")

# %%
category_funds=companies.groupby('category_code').sum()['funding_total_usd']
category_funds.plot(kind='bar',color=[set3[x] for x in [4,3,0,7,1]], grid= False, figsize=(20, 6), edgecolor='w', title="Total Funding per Category")
legend(loc='best')

# %%
status_name_counts=companies.groupby('status').count()[['name']]
status_name_counts.plot(kind='bar',color='b', figsize=(6, 6), title="Frequency of Status", edgecolor='w', grid= False)

# %%
founded_year=companies.founded_year.replace(0,nan).dropna()
founded_year.hist(bins=30, color='r', figsize=(8, 6), edgecolor='w', grid=False)

# %%
#regression on companies
#import statsmodels.formula.api as sm
#regression_frame= companies[[]]
#result = sm.ols(formula="A ~ B + C", data=df).fit()

# %%
investor_company=investments[['investor_name', 'company_name']]
investor_company.shape
investor_company.dropna(how='any')
investor_company.shape
# Out:
# (90283, 2)

# %% [markdown]
# ## Graph Mining

# %% [markdown]
# ### NOTE: plot() for igraph graphs is not working in ipython. The code given below is the same as the code in graphMining.R. Plots from this code is available in crunchbase git repository in plots() folder.

# %%
# %load_ext rmagic
import rpy2 as Rpy

# %%
# %%R
# library(igraph)
# #install.packages("Matrix")
# library(Matrix)
#
# investments=read.csv("/Users/Work/Documents/CS249/project/crunchbase/Data/investments.csv", header=TRUE)
# investments=na.omit(investments)
#
# #print(head(investments))
# print(dim(investments))
#
# investor_company=data.frame(investments$investor_name, investments$company_name)
# colnames(investor_company)=c("investor", "company")
#
# #taking top1000 companies and investors based on total funding
# company_names_top1000=read.csv("company_names_top1000.csv", header=TRUE)
# company_names_top110=company_names_top1000$name[1:150]
# investor_companytop110=subset(investor_company, company %in% company_names_top110)
# print(dim(investor_companytop110))
# #write.csv(company_investor_top1000, "company_investor_top1000.csv")
#
# #Using this dataframe
# investor_companytop110$investor= as.character(as.vector(investor_companytop110$investor))
# investor_companytop110$company= as.character(as.vector(investor_companytop110$company))
#
#
# #two mode incidence matrix to one mode adjacency matrix conversion
#
# #incidence matrix
# A= spMatrix(nrow=length(unique(investor_companytop110$investor)),
#             ncol=length(unique(investor_companytop110$company)),
#             i=as.numeric(factor(investor_companytop110$investor)),
#             j=as.numeric(factor(investor_companytop110$company)),
#             x=rep(1, length(as.numeric(investor_companytop110$investor))) )
#
# row.names(A)= levels(factor(investor_companytop110$investor))
# colnames(A)= levels(factor(investor_companytop110$company))
#
# iIC= graph.incidence(A, mode=c("all"))
#
# #plot two-made graph
# #check and change these index values everytime
# V(iIC)$color[1:571]= rgb(1,0,0,.5) #investors 1:2136 for top1000
# V(iIC)$color[572:681]= rgb(0,1,0,.5) #companies 2137:2967 for top1000
#
# V(iIC)$label = V(iIC)$name
# V(iIC)$label.color = rgb(0,0,.2,.5)
# V(iIC)$label.cex = .4
# V(iIC)$size = 6
# V(iIC)$frame.color = NA
#
# E(iIC)$color = rgb(.5,.5,0,.2)
#
# pdf("iIC_top110companies.pdf")
# plot(iIC, main="Two-mode incidence graph", layout=layout.fruchterman.reingold)
# dev.off()
#
# #clean the network by removing 1 degree edges
# iIC = delete.vertices(iIC, V(iIC)[ degree(iIC)==1 ])
# V(iIC)$label[1:230] = NA
# V(iIC)$color[1:230] = rgb(1,0,0,.1)
# V(iIC)$size[1:230] = 2
#
# E(iIC)$width = .3
# E(iIC)$color = rgb(.5,.5,0,.1)
#
# #trying different layouts
# #pdf("iIC_top110companies.2.pdf")
# #plot(iIC, main= "layout.kamada.kawai", layout=layout.kamada.kawai)
# #dev.off()
#
# #pdf("iIC_top110companies.3.pdf")
# #plot(iIC, main="layout.fruchterman.reingold.grid", layout=layout.fruchterman.reingold.grid)
# #dev.off()
#
# #gives best plot : it really emphasizes centrality–the nodes that are most central
# #are nearly always placed in the middle of the plot
# pdf("iIC_top110companies.4.pdf")
# plot(iIC, main="layout.fruchterman.reingold", layout=layout.fruchterman.reingold)
# dev.off()
# Out:
# [1] 90281    20
# [1] 1251    2
# Error in nchar(labels) : invalid multibyte string 172
# In addition: Warning messages:
# 1: In .M.kind(x) : NAs introduced by coercion
# 2: In vattrs[[name]][index] <- value :
#   number of items to replace is not a multiple of replacement length
# 3: In .M.kind(x) : NAs introduced by coercion
# 4: In vattrs[[name]][index] <- value :
#   number of items to replace is not a multiple of replacement length
# Error in nchar(labels) : invalid multibyte string 172

# %%
# %%R
#
# #Working with adjacency matrix
# print(head(A))
# Arow= tcrossprod(A) #adjacency matrix for investors
# print(head(Arow))
#
# Acol=tcrossprod(t(A)) #adjacency matrix for companies
# print(head(Acol))
#
# #adjacency matrix of investors
# Ainvestors= graph.adjacency(Arow, mode= "undirected")
#
# #we need to transform the graph so that multiply edges become an attribute
# E(Ainvestors)$weight = count.multiple(Ainvestors)
# Ainvestors = simplify(Ainvestors)
#
# #setting plotting parameters
# # Set vertex attributes
# V(Ainvestors)$label = V(Ainvestors)$name
# V(Ainvestors)$label.color = rgb(0,0,.2,.8)
# V(Ainvestors)$label.cex = .6
# V(Ainvestors)$size = 6
# V(Ainvestors)$frame.color = NA
# V(Ainvestors)$color = rgb(0,0,1,.5)
#
# # Set edge gamma according to edge weight
# egam <- (log(E(Ainvestors)$weight)+.3)/max(log(E(Ainvestors)$weight)+.3)
# E(Ainvestors)$color <- rgb(.5,.5,0,egam)
#
# pdf("Ainvestors_top110companies.pdf")
# plot(Ainvestors, main = "layout.kamada.kawai", layout=layout.kamada.kawai)
# plot(Ainvestors, main = "layout.fruchterman.reingold", layout=layout.fruchterman.reingold)
# dev.off()
#
# #adjacency matrix of companies
# Acompanies= graph.adjacency(Acol, mode= "undirected")
#
# #we need to transform the graph so that multiply edges become an attribute
# E(Acompanies)$weight = count.multiple(Acompanies)
# Acompanies = simplify(Acompanies)
#
# #setting plotting parameters
# # Set vertex attributes
# V(Acompanies)$label = V(Acompanies)$name
# V(Acompanies)$label.color = rgb(0,0,.2,.8)
# V(Acompanies)$label.cex = .6
# V(Acompanies)$size = 6
# V(Acompanies)$frame.color = NA
# V(Acompanies)$color = rgb(0,0,1,.5)
#
# # Set edge gamma according to edge weight
# egam <- (log(E(Acompanies)$weight)+.3)/max(log(E(Acompanies)$weight)+.3)
# E(Acompanies)$color <- rgb(.5,.5,0,egam)
#
# pdf("Acompanies_top110companies.pdf")
# plot(Acompanies, main = "layout.kamada.kawai", layout=layout.kamada.kawai)
# plot(Acompanies, main = "layout.fruchterman.reingold", layout=layout.fruchterman.reingold)
# dev.off()
# Out:
# Error in inherits(adjmatrix, "Matrix") : object 'Acol' not found

# %%
#overlap graph for investors
olInvestors= Arow/diag(Arow)
olInvestors=as.matrix(olInvestors)
olInvestorsg= graph.adjacency(olInvestors, weighted=T)

#Degree
V(olInvestorsg)$degree= degree(olInvestorsg)

#Betweenness centrality
V(olInvestorsg)$btwcnt= betweenness(olInvestorsg)

#distribution of connection strength
plot(density(olInvestors), main="Distribution of Connection Strength")

#filter at 1 so that an edge will consists of investor overlap of more than 1 of the investor’s companies in question
olInvestors1 = olInvestors
#olInvestors1[olInvestors<0.5] = 0
olInvestor1g = graph.adjacency(olInvestors1, weighted=T)

#remove loops
olInvestor1g<- simplify(olInvestor1g, remove.multiple=FALSE, remove.loops=TRUE)

#hand placing nodes to make sure no labels overlap
olInvestor1g$layout <- layout.fruchterman.reingold(olInvestor1g)
V(olInvestor1g)$label <- V(olInvestor1g)$name
tkplot(olInvestor1g)

#save layout
olInvestor1g$layout <- tkplot.getcoords(4)

# Set vertex attributes
V(olInvestor1g)$label <- V(olInvestor1g)$name
V(olInvestor1g)$label.color <- rgb(250/256,128/256,114/256, 0.5)
V(olInvestor1g)$size <- 6
V(olInvestor1g)$frame.color <- NA
V(olInvestor1g)$color <- rgb(95/256,158/256,160/256,.5)
 
# Set edge attributes
E(olInvestor1g)$arrow.size <- .3
 
# Set edge gamma according to edge weight
egam <- (E(olInvestor1g)$weight+.1)/max(E(olInvestor1g)$weight+.1)
E(olInvestor1g)$color <- rgb(0.5,0.5,0,0.1)

V(olInvestor1g)$label.cex <- V(olInvestor1g)$degree/(max(V(olInvestor1g)$degree)/2)
#note, unfortunately one must play with the formula above to get the
#ratio just right

pdf("olInvestor1gcustomlayout.pdf")
plot(olInvestor1g)
dev.off()
